# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("gplay1.csv")

# %%
df=df.head(5)

# %%
df
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating   Reviews  Size     Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1     159.0   19M      10,000+  Free     0
# 1  ART_AND_DESIGN     3.9     967.0   14M     500,000+  Free     0
# 2  ART_AND_DESIGN     4.7   87510.0  8.7M   5,000,000+  Free     0
# 3  ART_AND_DESIGN     4.5  215644.0   25M  50,000,000+  Free     0
# 4  ART_AND_DESIGN     4.3     967.0  2.8M     100,000+  Free     0
#
#   Content Rating
# 0       Everyone
# 1       Everyone
# 2       Everyone
# 3           Teen
# 4       Everyone

# %%
# way1
df.drop(['Unnamed: 0'],axis=1)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
# 4     967.0  2.8M     100,000+  Free     0       Everyone

# %%
# way2
df.drop(columns='Unnamed: 0')
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type Price Content Rating
# 0     159.0   19M      10,000+  Free     0       Everyone
# 1     967.0   14M     500,000+  Free     0       Everyone
# 2   87510.0  8.7M   5,000,000+  Free     0       Everyone
# 3  215644.0   25M  50,000,000+  Free     0           Teen
# 4     967.0  2.8M     100,000+  Free     0       Everyone

# %%
# how to drop multiple columns

# %%
df.drop(['Unnamed: 0','Category'],axis=1)
# Out:
#                                                  App  Rating   Reviews  Size  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1     159.0   19M
# 1                                Coloring book moana     3.9     967.0   14M
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7   87510.0  8.7M
# 3                              Sketch - Draw & Paint     4.5  215644.0   25M
# 4              Pixel Draw - Number Art Coloring Book     4.3     967.0  2.8M
#
#       Installs  Type Price Content Rating
# 0      10,000+  Free     0       Everyone
# 1     500,000+  Free     0       Everyone
# 2   5,000,000+  Free     0       Everyone
# 3  50,000,000+  Free     0           Teen
# 4     100,000+  Free     0       Everyone

# %%
df.drop(columns=['Unnamed: 0','Category'])
# Out:
#                                                  App  Rating   Reviews  Size  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1     159.0   19M
# 1                                Coloring book moana     3.9     967.0   14M
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7   87510.0  8.7M
# 3                              Sketch - Draw & Paint     4.5  215644.0   25M
# 4              Pixel Draw - Number Art Coloring Book     4.3     967.0  2.8M
#
#       Installs  Type Price Content Rating
# 0      10,000+  Free     0       Everyone
# 1     500,000+  Free     0       Everyone
# 2   5,000,000+  Free     0       Everyone
# 3  50,000,000+  Free     0           Teen
# 4     100,000+  Free     0       Everyone

# %%
# how to drop at row level

# %%
df.drop([0,1])    # default work on axis=0
# Out:
#    Unnamed: 0                                                App  \
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating   Reviews  Size     Installs  Type Price  \
# 2  ART_AND_DESIGN     4.7   87510.0  8.7M   5,000,000+  Free     0
# 3  ART_AND_DESIGN     4.5  215644.0   25M  50,000,000+  Free     0
# 4  ART_AND_DESIGN     4.3     967.0  2.8M     100,000+  Free     0
#
#   Content Rating
# 2       Everyone
# 3           Teen
# 4       Everyone

# %%
df.drop(index=(3))
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews  Size    Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1    159.0   19M     10,000+  Free     0
# 1  ART_AND_DESIGN     3.9    967.0   14M    500,000+  Free     0
# 2  ART_AND_DESIGN     4.7  87510.0  8.7M  5,000,000+  Free     0
# 4  ART_AND_DESIGN     4.3    967.0  2.8M    100,000+  Free     0
#
#   Content Rating
# 0       Everyone
# 1       Everyone
# 2       Everyone
# 4       Everyone

# %%
df.drop(index=([3,4]))
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
#
#          Category  Rating  Reviews  Size    Installs  Type Price  \
# 0  ART_AND_DESIGN     4.1    159.0   19M     10,000+  Free     0
# 1  ART_AND_DESIGN     3.9    967.0   14M    500,000+  Free     0
# 2  ART_AND_DESIGN     4.7  87510.0  8.7M  5,000,000+  Free     0
#
#   Content Rating
# 0       Everyone
# 1       Everyone
# 2       Everyone

# %%
# how to drop row and columns at a same time
df.drop(index=1,columns="App")
# Out:
#    Unnamed: 0        Category  Rating   Reviews  Size     Installs  Type  \
# 0           0  ART_AND_DESIGN     4.1     159.0   19M      10,000+  Free
# 2           2  ART_AND_DESIGN     4.7   87510.0  8.7M   5,000,000+  Free
# 3           3  ART_AND_DESIGN     4.5  215644.0   25M  50,000,000+  Free
# 4           4  ART_AND_DESIGN     4.3     967.0  2.8M     100,000+  Free
#
#   Price Content Rating
# 0     0       Everyone
# 2     0       Everyone
# 3     0           Teen
# 4     0       Everyone

# %%
df.drop(index=(list(df[1:4].index)))
# Out:
#    Unnamed: 0                                             App        Category  \
# 0           0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 4           4           Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#    Rating  Reviews  Size  Installs  Type Price Content Rating
# 0     4.1    159.0   19M   10,000+  Free     0       Everyone
# 4     4.3    967.0  2.8M  100,000+  Free     0       Everyone
